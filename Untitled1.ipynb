# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('falldeteciton.csv')

# %%
df['TIME'].hist()

# %%
import seaborn as sns
sns.boxplot(x=df['TIME'])

# %%
df['SL'].hist()

# %%
import seaborn as sns
sns.boxplot(x=df['SL'])

# %%
df['EEG'].hist()

# %%
sns.boxplot(x=df['EEG'])

# %%
df['BP'].hist()

# %%
sns.boxplot(x=df['BP'])

# %%
df['HR'].hist()

# %%
sns.boxplot(x=df['HR'])

# %%
df['CIRCLUATION'].hist()

# %%
sns.boxplot(x=df['CIRCLUATION'])

# %%
plt.scatter(df['BP'],df['SL'])
plt.xlabel('Blood Pressure')
plt.ylabel('Sugar Level')
# Out:
# Text(0, 0.5, 'Sugar Level')

# %%
plt.scatter(df['CIRCLUATION'],df['SL'])
plt.xlabel('Blood Circulation')
plt.ylabel('Sugar Level')
# Out:
# Text(0, 0.5, 'Sugar Level')
