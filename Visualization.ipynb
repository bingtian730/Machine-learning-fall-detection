# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('fall_new.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  ACTIVITY     TIME        SL      EEG  BP   HR  CIRCLUATION  \
# 0           0         3  4722.92   4019.64 -1600.00  13   79          317
# 1           1         2  4059.12   2191.03 -1146.08  20   54          165
# 2           2         2  4773.56   2787.99 -1263.38  46   67          224
# 3           3         4  8271.27   9545.98 -2848.93  26  138          554
# 4           4         4  7102.16  14148.80 -2381.15  85  120          809
#
#    FALL
# 0     1
# 1     0
# 2     0
# 3     0
# 4     0

# %%
import seaborn as sns; sns.set()

# %%
SL_BP=df.pivot('SL','ACTIVITY','BP')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-b2a2ef57f787> in <module>()
# ----> 1 SL_BP=df.pivot('SL','ACTIVITY','BP')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5189         """
#    5190         from pandas.core.reshape.reshape import pivot
# -> 5191         return pivot(self, index=index, columns=columns, values=values)
#    5192
#    5193     _shared_docs['pivot_table'] = """
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     407             indexed = self._constructor_sliced(self[values].values,
#     408                                                index=index)
# --> 409     return indexed.unstack(columns)
#     410
#     411
#
# ...

# %%
df_fall=df[df['FALL']==1]

# %%
df_fall.shape
# Out:
# (3457, 9)

# %%
df_nfall=df[df['FALL']==0]

# %%
df_nfall.shape
# Out:
# (11914, 9)

# %%
df_fall['TIME'].hist()

# %%
df_nfall['TIME'].hist()

# %%
df_fall['SL'].hist()

# %%
df_nfall['SL'].hist()

# %%
plt.boxplot([df_fall['SL'],df_nfall['SL']])
plt.title('Sugar level box plot FALL VS NOT_FALL')
# Out:
# Text(0.5, 1.0, 'Sugar level box plot FALL VS NOT_FALL')

# %%
df_fall['EEG'].hist()

# %%
df_nfall['EEG'].hist()

# %%
plt.boxplot([df_fall['EEG'],df_nfall['EEG']])
plt.title('EEG monitoring rate box plot FALL VS NOT_FALL')
# Out:
# Text(0.5, 1.0, 'EEG monitoring rate box plot FALL VS NOT_FALL')

# %%
df_fall['BP'].hist()

# %%
df_nfall['BP'].hist()

# %%
plt.boxplot([df_fall['BP'],df_nfall['BP']])
plt.title('Blood Pressure box plot FALL VS NOT_FALL')
# Out:
# Text(0.5, 1.0, 'Blood Pressure box plot FALL VS NOT_FALL')

# %%
df_fall['HR'].hist()

# %%
df_nfall['HR'].hist()

# %%
plt.boxplot([df_fall['HR'],df_nfall['HR']])
plt.title('Heart Rate box plot FALL VS NOT_FALL')
# Out:
# Text(0.5, 1.0, 'Heart Rate box plot FALL VS NOT_FALL')

# %%
plt.boxplot([df_fall['CIRCLUATION'],df_nfall['CIRCLUATION']])
plt.title('Blood Circulation box plot FALL VS NOT_FALL')
# Out:
# Text(0.5, 1.0, 'Blood Circulation box plot FALL VS NOT_FALL')

# %%
plt.scatter(df['BP'],df['CIRCLUATION'])

# %%
plt.scatter(df_fall['BP'],df_fall['CIRCLUATION'])

# %%
plt.scatter(df_nfall['BP'],df_nfall['CIRCLUATION'])

# %%
plt.scatter(df['BP'],df['SL'])

# %%
plt.scatter(df_fall['BP'],df_fall['SL'])

# %%
plt.scatter(df_nfall['BP'],df_nfall['SL'])
